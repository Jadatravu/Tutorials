# %%
import pandas as pd
import numpy as np

# %%
import xlrd

# %%
xls = pd.ExcelFile('/Users/GGS/Downloads/global_superstore/Global Superstore.xls')

# %%
df1=pd.read_excel(xls,"Orders")

# %%
df1.shape
# Out:
# (51290, 24)

# %% [markdown]
# # 1. Random Sampling
# In a simple random sample (SRS) of a given size, all such subsets of the frame are given an equal probability.
#  This minimizes bias and simplifies analysis of results.

# %% [markdown]
# #  1.1 New Column " Sample_order " with random number generation

# %%
df1["sample_order"]=np.random.rand(df1.shape[0],1)

# %% [markdown]
# # 1.2 Sorting the dataframe based on the values of "sample_order" column in descending order

# %%
df1_sorted=df1.sort_values(["sample_order"],ascending=[False])
#df1.sort(['a', 'b'], ascending=[True, False])

# %% [markdown]
# # 1.3 selecting only top n(100 in this example) samples of the dataframe

# %%
df1_sorted.iloc[:100,:]
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 12099   23424    IN-2014-15767 2014-08-22 2014-08-27  Standard Class
# 31232   36436   CA-2014-128335 2014-09-30 2014-10-06  Standard Class
# 44148   49547     LH-2012-9290 2012-03-06 2012-03-09    Second Class
# 11571   42670     UP-2013-5950 2013-04-04 2013-04-08    Second Class
# 25276   22390    IN-2014-13212 2014-11-20 2014-11-25  Standard Class
# 15644   31946   CA-2013-160745 2013-12-12 2013-12-17    Second Class
# 30124   19376  ES-2012-2360362 2012-08-03 2012-08-07  Standard Class
# 26262   28083    IN-2013-13149 2013-12-16 2013-12-18    Second Class
# 3453    33538   US-2013-126893 2013-11-27 2013-12-02  Standard Class
# 29083   19144  ES-2014-4451711 2014-07-30 2014-08-04  Standard Class
# 15985   44602     RW-2013-8370 2013-02-07 2013-02-12    Second Class
# 50744   35063   CA-2013-163153 2013-03-22 2013-03-26  Standard Class
# 16952   48189     SF-2013-2340 2013-11-09 2013-11-11     First Class
# ...

# %% [markdown]
# # 1.4 selecting only top n(500 in this example) samples of the dataframe

# %%
df1_sorted.iloc[:500,:]
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 12099   23424    IN-2014-15767 2014-08-22 2014-08-27  Standard Class
# 31232   36436   CA-2014-128335 2014-09-30 2014-10-06  Standard Class
# 44148   49547     LH-2012-9290 2012-03-06 2012-03-09    Second Class
# 11571   42670     UP-2013-5950 2013-04-04 2013-04-08    Second Class
# 25276   22390    IN-2014-13212 2014-11-20 2014-11-25  Standard Class
# 15644   31946   CA-2013-160745 2013-12-12 2013-12-17    Second Class
# 30124   19376  ES-2012-2360362 2012-08-03 2012-08-07  Standard Class
# 26262   28083    IN-2013-13149 2013-12-16 2013-12-18    Second Class
# 3453    33538   US-2013-126893 2013-11-27 2013-12-02  Standard Class
# 29083   19144  ES-2014-4451711 2014-07-30 2014-08-04  Standard Class
# 15985   44602     RW-2013-8370 2013-02-07 2013-02-12    Second Class
# 50744   35063   CA-2013-163153 2013-03-22 2013-03-26  Standard Class
# 16952   48189     SF-2013-2340 2013-11-09 2013-11-11     First Class
# ...

# %% [markdown]
# # 2 Stratified Sampling
# When the population embraces a number of distinct categories, the frame can be organized by these categories into separate "strata." Each stratum is then sampled as an independent sub-population, out of which individual elements can be randomly selected.
# two advantages of this sampling
# First, dividing the population into distinct, independent strata can enable researchers to draw inferences about specific subgroups that may be lost in a more generalized random sample
# Second, utilizing a stratified sampling method can lead to more efficient statistical estimates

# %%
df1["Category"].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %% [markdown]
# # 2.1 Making Groups based on Category

# %%
df1_technology = df1[df1["Category"]=="Technology"]
df1_furniture = df1[df1["Category"]=="Furniture"]
df1_oc = df1[df1["Category"]=="Office Supplies"]

# %% [markdown]
# # 2.2 Sorting categories based the values  of "sample_order" column

# %%
df1_technology_sorted = df1_technology.sort_values(["sample_order"],ascending=[False])
df1_furniture_sorted = df1_furniture.sort_values(["sample_order"],ascending=[False])
df1_oc_sorted = df1_oc.sort_values(["sample_order"],ascending=[False])

# %% [markdown]
# # 2.3 Taking top 33(for total 100 samples) of each category

# %%
df1_technology_sorted_sam = df1_technology_sorted.iloc[:33,:]
df1_furniture_sorted_sam = df1_furniture_sorted.iloc[:33,:]
df1_oc_sorted_sam = df1_oc_sorted.iloc[:33,:]

# %% [markdown]
# # 2.4 Concatening the three dataframes into one

# %%
df1_st_sample=pd.concat([df1_technology_sorted_sam,df1_furniture_sorted_sam,df1_oc_sorted_sam],axis=0)

# %% [markdown]
# # 2.5 sorting based on Row Id column similar to the original dataframe

# %%
df1_st_sample.sort_values(["Row ID"],ascending=[False],inplace=True)

# %%
df1_st_sample[df1_st_sample["Category"]=="Technology"]
# Out:
#        Row ID         Order ID Order Date  Ship Date       Ship Mode  \
# 2408    51089     GH-2014-4170 2014-07-10 2014-07-13     First Class
# 12109   48832     MO-2013-4260 2013-09-19 2013-09-25  Standard Class
# 6013    48078     UP-2012-1130 2012-09-16 2012-09-21  Standard Class
# 15985   44602     RW-2013-8370 2013-02-07 2013-02-12    Second Class
# 23089   44510     TU-2013-9320 2013-09-03 2013-09-07  Standard Class
# 4454    41353     TS-2012-3120 2012-01-21 2012-01-23     First Class
# 3453    33538   US-2013-126893 2013-11-27 2013-12-02  Standard Class
# 43287   32173   CA-2013-116736 2013-01-17 2013-01-21  Standard Class
# 15644   31946   CA-2013-160745 2013-12-12 2013-12-17    Second Class
# 31442   31906   US-2011-105767 2011-05-23 2011-05-27  Standard Class
# 90      29600    IN-2012-48240 2012-05-25 2012-05-28    Second Class
# 23561   28926    IN-2014-50088 2014-08-27 2014-09-01  Standard Class
# 11036   28429    IN-2014-55471 2014-09-12 2014-09-16  Standard Class
# ...

# %%
df1_st_sample.shape
# Out:
# (99, 25)

# %%
len(df1["State"].unique())
# Out:
# 1094

# %%
df1["State"]
# Out:
# 0                 New York
# 1          New South Wales
# 2               Queensland
# 3                   Berlin
# 4                    Dakar
# 5          New South Wales
# 6               Wellington
# 7                  Waikato
# 8               California
# 9           North Carolina
# 10                Virginia
# 11                   Kabul
# 12                   Jizan
# 13                  Parana
# 14            Heilongjiang
# 15           Ile-de-France
# 16                Kentucky
# 17                 Tuscany
# 18              Queensland
# 19                  Kigoma
# 20                 Silesia
# 21                Illinois
# 22                   Anhui
# 23                Scotland
# 24               Chihuahua
# 25            San Salvador
# 26             Taipei City
# 27                  Saxony
# 28              California
# 29                 Gujarat
#                ...
# 51260                Idaho
# 51261               Kaluga
# 51262             Manitoba
# ...

# %% [markdown]
# # 3 Systematic sampling
# Systematic sampling (also known as interval sampling) relies on arranging the study population according to some ordering scheme and then selecting elements at regular intervals through that ordered list. Systematic sampling involves a random start and then proceeds with the selection of every kth element from then onwards

# %% [markdown]
# # 4 Cluster sampling
# Sometimes it is more cost-effective to select respondents in groups ('clusters'). Sampling is often clustered by geography, or by time periods

# %% [markdown]
# # Difference between Stratified Sampling and Cluster Sampling?
# • In stratified sampling, the population is divided into homogeneous groups called strata, using an attribute of the samples. Then members from each stratum are selected, and the number of samples taken from those strata is proportional to the presence of the strata within the population.
# • In cluster sampling, the population is grouped into clusters, predominantly based on location, and then a cluster is selected at random.
# • In cluster sampling, a cluster is selected at random, whereas in stratified sampling members are selected at random.
# • In stratified sampling, each group used (strata) include homogenous members while, in cluster sampling, a cluster is heterogeneous.
# • Stratified sampling is slower while cluster sampling is relatively faster.
# • Stratified samples have less error due to factoring in the presence of each group within the population and adapting the methods to obtain a better estimation.
# • Cluster sampling has inherent higher percentage of error.
