# %%
import pandas as pd
import xlrd

# %%
#https://public.tableau.com/s/resources?qt-overview_resources=1
#https://public.tableau.com/s/sites/default/files/media/Resources/pokemon.xlsx

# %%
xls = pd.ExcelFile("C:/Users/surya.adatravu/Desktop/Kaggle/global_superstore/pokemon.xlsx")

# %%
xls.sheet_names
# Out:
# ['Pokemon', 'Moves', 'Evolution', 'TypeChart']

# %%
df1=pd.read_excel(xls,"Pokemon")

# %%
df1.columns
# Out:
# Index(['#', 'Name', 'Type', 'Total', 'HP', 'Attack', 'Defense',
#        'Special Attack', 'Special Defense', 'Speed'],
#       dtype='object')

# %%
df1.dtypes
# Out:
# #                  object
# Name               object
# Type               object
# Total               int64
# HP                  int64
# Attack              int64
# Defense             int64
# Special Attack      int64
# Special Defense     int64
# Speed               int64
# dtype: object

# %%
import seaborn as sns

# %%
plt.figure(figsize=(50, 10))
sns.lineplot(x='Total',y='Attack',hue='Type',data=df1)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(50, 10))
g=sns.barplot(x='Total',y='Attack',hue='Type',data=df1)

# %%
plt.figure(figsize=(50, 10))
g=sns.barplot(x='Type',y='Attack',data=df1)

# %%
df2=df1.drop(['#', 'Name', 'Type', 'Total'],axis=1)

# %%
df2.columns
# Out:
# Index(['HP', 'Attack', 'Defense', 'Special Attack', 'Special Defense',
#        'Speed'],
#       dtype='object')

# %%
sns.pairplot(data=df2)

# %%
g=sns.catplot(x='Type',y='Total', kind='bar',data=df1)
g.fig.set_size_inches(15,15)

# %%
plt.figure(figsize=(10, 10))
sns.lineplot(x='Total',y='Attack',data=df1)

# %%
plt.figure(figsize=(10, 10))
sns.distplot(df1.Attack)

# %%
plt.figure(figsize=(10, 10))
sns.distplot(df1.Speed)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Total", y="Defense", data=df1)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Total", y="Attack",
                      hue="Type",
                      data=df1)

# %%
plt.figure(figsize=(50, 30))
sns.heatmap(data=df2)

# %%
df3=df1.drop(['#', 'Name'],axis=1)

# %%
#https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.pairplot(data=df3,hue='Type',palette=sns.color_palette("cubehelix", 8))

# %%
plt.figure(figsize=(50, 30))
sns.heatmap(data=df2,cmap="YlGnBu")

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Defense", y="Attack",s=df1['HP'].values,  hue='Type',data=df1)

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x="Total", y="Attack",s=df1['Special Attack'].values,  hue='Type',data=df1)

# %%
df3=df1[['Total', 'HP', 'Attack', 'Defense','Special Attack', 'Special Defense', 'Speed']]

# %%
df3_corr = df3.corr()

# %%
sns.heatmap(data=df3_corr,cmap='rainbow',annot=True)

# %%
plt.figure(figsize=(50, 30))
sns.boxplot(x='Type',y='Total',data=df1)

# %%
plt.figure(figsize=(50, 30))
sns.barplot(data=df1,orient='h')
