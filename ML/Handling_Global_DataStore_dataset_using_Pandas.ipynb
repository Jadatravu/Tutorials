# %%
import pandas as pd
import xlrd

# %%
#dataset from url "https://www.tableau.com/sites/default/files/training/global_superstore.zip"
xls = pd.ExcelFile('/Users/GGS/Downloads/global_superstore/Global Superstore.xls')

# %%
xls.sheet_names
# Out:
# ['Orders', 'Returns', 'People']

# %%
df1=pd.read_excel(xls,"Orders")

# %%
df1.shape
# Out:
# (51290, 24)

# %%
df1.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  \
# 0       Rick Hansen     Consumer  New York City         New York
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#         ...              Product ID    Category Sub-Category  \
# ...

# %%
df1.head()
# Out:
#    Row ID         Order ID Order Date  Ship Date     Ship Mode Customer ID  \
# 0   32298   CA-2012-124891 2012-07-31 2012-07-31      Same Day    RH-19495
# 1   26341    IN-2013-77878 2013-02-05 2013-02-07  Second Class    JR-16210
# 2   25330    IN-2013-71249 2013-10-17 2013-10-18   First Class    CR-12730
# 3   13524  ES-2013-1579342 2013-01-28 2013-01-30   First Class    KM-16375
# 4   47221     SG-2013-4320 2013-11-05 2013-11-06      Same Day     RH-9495
#
#       Customer Name      Segment           City            State  \
# 0       Rick Hansen     Consumer  New York City         New York
# 1     Justin Ritter    Corporate     Wollongong  New South Wales
# 2      Craig Reiter     Consumer       Brisbane       Queensland
# 3  Katherine Murray  Home Office         Berlin           Berlin
# 4       Rick Hansen     Consumer          Dakar            Dakar
#
#         ...              Product ID    Category Sub-Category  \
# ...

# %%
df1.dtypes
# Out:
# Row ID                     int64
# Order ID                  object
# Order Date        datetime64[ns]
# Ship Date         datetime64[ns]
# Ship Mode                 object
# Customer ID               object
# Customer Name             object
# Segment                   object
# City                      object
# State                     object
# Country                   object
# Postal Code              float64
# Market                    object
# Region                    object
# Product ID                object
# Category                  object
# Sub-Category              object
# Product Name              object
# Sales                    float64
# Quantity                   int64
# Discount                 float64
# Profit                   float64
# Shipping Cost            float64
# Order Priority            object
# dtype: object

# %%
df1.groupby("City")["Sales"].mean()
# Out:
# City
# Aachen                   223.714765
# Aalen                    979.695000
# Aalst                     96.832500
# Aba                       42.564960
# Abadan                   123.177273
# Abakaliki                 17.163000
# Abbeville                 72.610000
# Abbotsford                98.580000
# Abeokuta                  13.344750
# Aberdeen                 262.225000
# Abha                     200.437500
# Abidjan                  213.048947
# Abilene                    1.392000
# Abreu e Lima             928.256000
# Abu Kabir                121.635000
# Abuja                     19.008000
# Acarigua                 119.772000
# Acayucan                  81.099893
# Accra                    225.458696
# Acerra                   680.655000
# Acireale                 129.915600
# Acuña                    221.337846
# Acámbaro                 136.358667
# Ad Diwaniyah             298.761429
# Ad Diwem                  98.013750
# Adana                     78.837061
# ...

# %%
df1["Category"].unique()
# Out:
# array(['Technology', 'Furniture', 'Office Supplies'], dtype=object)

# %%
df1["Segment"].describe()
# Out:
# count        51290
# unique           3
# top       Consumer
# freq         26518
# Name: Segment, dtype: object

# %%
df1.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'City', 'State', 'Country',
#        'Postal Code', 'Market', 'Region', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
df1[df1["Segment"]=="Consumer"].head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0   32298  CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 2   25330   IN-2013-71249 2013-10-17 2013-10-18     First Class    CR-12730
# 4   47221    SG-2013-4320 2013-11-05 2013-11-06        Same Day     RH-9495
# 6   30570   IN-2011-81826 2011-11-07 2011-11-09     First Class    TS-21340
# 7   31192   IN-2012-86369 2012-04-14 2012-04-18  Standard Class    MB-18085
#
#    Customer Name   Segment           City       State       ...        \
# 0    Rick Hansen  Consumer  New York City    New York       ...
# 2   Craig Reiter  Consumer       Brisbane  Queensland       ...
# 4    Rick Hansen  Consumer          Dakar       Dakar       ...
# 6  Toby Swindell  Consumer        Porirua  Wellington       ...
# 7     Mick Brown  Consumer       Hamilton     Waikato       ...
#
#          Product ID    Category Sub-Category  \
# 0   TEC-AC-10003033  Technology  Accessories
# ...

# %%
df1[(df1["Segment"]=="Consumer") & (df1["State"]=="New York")].head()
# Out:
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     32298  CA-2012-124891 2012-07-31 2012-07-31        Same Day    RH-19495
# 36    36423  CA-2011-160766 2011-09-14 2011-09-14        Same Day    DM-13015
# 50    40046  US-2012-163825 2012-06-16 2012-06-19     First Class    LC-16885
# 121   37923  CA-2011-145541 2011-12-14 2011-12-21  Standard Class    TB-21400
# 147   32998  CA-2012-114069 2012-07-13 2012-07-15    Second Class    ND-18370
#
#          Customer Name   Segment           City     State       ...        \
# 0          Rick Hansen  Consumer  New York City  New York       ...
# 36       Darrin Martin  Consumer  New York City  New York       ...
# 50      Lena Creighton  Consumer  New York City  New York       ...
# 121   Tom Boeckenhauer  Consumer  New York City  New York       ...
# 147  Natalie DeCherney  Consumer  New York City  New York       ...
#
#           Product ID         Category Sub-Category  \
# ...

# %%
df1.describe().transpose()
# Out:
#                  count          mean           std       min           25%  \
# Row ID         51290.0  25645.500000  14806.291990     1.000  12823.250000
# Postal Code     9994.0  55190.379428  32063.693350  1040.000  23223.000000
# Sales          51290.0    246.490581    487.565361     0.444     30.758625
# Quantity       51290.0      3.476545      2.278766     1.000      2.000000
# Discount       51290.0      0.142908      0.212280     0.000      0.000000
# Profit         51290.0     28.610982    174.340972 -6599.978      0.000000
# Shipping Cost  51290.0     26.375818     57.296810     0.002      2.610000
#
#                      50%         75%        max
# Row ID         25645.500  38467.7500  51290.000
# Postal Code    56430.500  90008.0000  99301.000
# Sales             85.053    251.0532  22638.480
# Quantity           3.000      5.0000     14.000
# Discount           0.000      0.2000      0.850
# Profit             9.240     36.8100   8399.976
# ...

# %%
df1.isnull().sum()
# Out:
# Row ID                0
# Order ID              0
# Order Date            0
# Ship Date             0
# Ship Mode             0
# Customer ID           0
# Customer Name         0
# Segment               0
# City                  0
# State                 0
# Country               0
# Postal Code       41296
# Market                0
# Region                0
# Product ID            0
# Category              0
# Sub-Category          0
# Product Name          0
# Sales                 0
# Quantity              0
# Discount              0
# Profit                0
# Shipping Cost         0
# Order Priority        0
# dtype: int64

# %%
df1["Postal Code"].mode()
# Out:
# 0    10035.0
# dtype: float64

# %%
df1["Postal Code"].head()
# Out:
# 0    10024.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# Name: Postal Code, dtype: float64

# %%
df1["Sales"].mean()
# Out:
# 246.49058120257362

# %%
df1["Sales"].median()
# Out:
# 85.053

# %%
df1["Order Priority"].describe()
# Out:
# count      51290
# unique         4
# top       Medium
# freq       29433
# Name: Order Priority, dtype: object

# %%
df1["Order Priority"].unique()
# Out:
# array(['Critical', 'Medium', 'High', 'Low'], dtype=object)
